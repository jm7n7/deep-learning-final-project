# %% [markdown]
# <a href="https://colab.research.google.com/github/jm7n7/deep-learning-final-project/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Project: Multi-Object Tracking with Video
# ##### Jim Huynh | Joseph Marinello | Ailing Nan | Kenny Phan

# %% [markdown]
# ## Assignment Overview

# %% [markdown]
# ### Project Objectives
# *   Parse & prepare data
# *   Tune pre-trained model
# *   Implement tracking system
# *   Generate bounding boxes with ID's on testing set

# %% [markdown]
# ### Evaluation Goals (Grading Rubric)
# * A: Perfect bounding box tracking across all frames
# * B: Tracking bounding box on most frames
# * C: Can detect object with bounding box, but little to no tracking
# * D: Object detection with some bounding box, but no tracking
# * F: No object detection

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/Deep_Learning/Final_Project
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Deep_Learning/Final_Project

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Data Gathering

# %%
def parse_gt_file(file_path):
  data = []
  with open(file_path, 'r') as f:
    pass
  return data

# %%
print("Hello World")
